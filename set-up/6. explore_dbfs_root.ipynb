# %% [markdown]
# # Explore DBFS Root
# 1. List all the folders in DBFS roote
# 2. Interact with DBFS File Browser
# 3. Upload file to DBFS root

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/FileStore'))

# %%
display(spark.read.csv('dbfs:/FileStore/circuits.csv'))
