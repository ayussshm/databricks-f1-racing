-- %% [markdown]
-- ## External Locations

-- %%
CREATE EXTERNAL LOCATION {external_location_name}
URL 'abfss://bronze@{storage_account}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-credential`)

-- %%
CREATE EXTERNAL LOCATION {external_location_name}
URL 'abfss://silver@{storage_account}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-credential`)

-- %%
CREATE EXTERNAL LOCATION {external_location_name}
URL 'abfss://gold@{storage_account}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-credential`)

-- %% [markdown]
-- ## Create Catalogs and schemas required for the project

-- %%
CREATE CATALOG IF NOT EXISTS formula1;

-- %%
USE CATALOG formula1;

-- %%
CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION 'abfss://bronze@{storage_account}.dfs.core.windows.net/'

-- %%
CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION 'abfss://silver@{storage_account}.dfs.core.windows.net/'

-- %%
CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION 'abfss://gold@{storage_account}.dfs.core.windows.net/'
