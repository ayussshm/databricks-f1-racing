# %%
bronze_folder_path = 'abfss://bronze@{storage-account}.dfs.core.windows.net'
silver_folder_path = 'abfss://silver@{storage-account}.dfs.core.windows.net'
gold_folder_path = 'abfss://gold@{storage-account}.dfs.core.windows.net'
