# %%
raw_folder_path = '/mnt/formula1dl244/raw'
processed_folder_path = '/mnt/formula1dl244/processed'
presentation_folder_path = '/mnt/formula1dl244/presentation'

# %%
bronze_folder_path = 'abfss://bronze@formula1dl244.dfs.core.windows.net'
silver_folder_path = 'abfss://silver@formula1dl244.dfs.core.windows.net'
gold_folder_path = 'abfss://gold@formula1dl244.dfs.core.windows.net'
